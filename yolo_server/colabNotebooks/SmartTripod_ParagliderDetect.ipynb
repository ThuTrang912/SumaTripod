# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17045, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 17045 (delta 10), reused 18 (delta 8), pack-reused 17022 (from 1)
# Receiving objects: 100% (17045/17045), 15.66 MiB | 17.23 MiB/s, done.
# Resolving deltas: 100% (11700/11700), done.

# %%
# !pip install -r /content/yolov5/requirements.txt  # install
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 886.3/886.3 kB 23.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# Kéo thả để upload folder đã zip được tài về từ Roboflow được format theo yolov5

# %%
# !unzip /content/roboflowParagliderDatasets.zip -d /content/yolov5/dataset
# Out:
# Archive:  /content/roboflowParagliderDatasets.zip
#    creating: /content/yolov5/dataset/roboflowParagliderDatasets/
#   inflating: /content/yolov5/dataset/roboflowParagliderDatasets/data.yaml
#   inflating: /content/yolov5/dataset/roboflowParagliderDatasets/README.dataset.txt
#   inflating: /content/yolov5/dataset/roboflowParagliderDatasets/README.roboflow.txt
#    creating: /content/yolov5/dataset/roboflowParagliderDatasets/test/
#    creating: /content/yolov5/dataset/roboflowParagliderDatasets/test/images/
#   inflating: /content/yolov5/dataset/roboflowParagliderDatasets/test/images/Image12_png.rf.7077ebe67160b78d93abf1c30abe028a.jpg
#   inflating: /content/yolov5/dataset/roboflowParagliderDatasets/test/images/Image8_png.rf.6a5352fa6cea6221a4c0240c81963901.jpg
#    creating: /content/yolov5/dataset/roboflowParagliderDatasets/test/labels/
#   inflating: /content/yolov5/dataset/roboflowParagliderDatasets/test/labels/Image12_png.rf.7077ebe67160b78d93abf1c30abe028a.txt
# ...

# %% [markdown]
# Mở data.yaml để thay đổi đường dẫn đến train/images....

# %%
# !python /content/yolov5/train.py --img 640 --epochs 100 --data /content/yolov5/dataset/roboflowParagliderDatasets/data.yaml --weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-11-15 07:24:41.381183: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-15 07:24:41.401193: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-15 07:24:41.407307: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# ...

# %% [markdown]
# Cải thiệt mô hình bằng cách huấn luyện thêm vào mô hinh best.pt

# %%
# !python /content/yolov5/train.py --img 640 --epochs 100 --data /content/yolov5/dataset/roboflowParagliderDatasets/data.yaml --weights /content/yolov5/runs/train/exp3/weights/best.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-11-15 07:42:49.611234: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-15 07:42:49.631050: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-15 07:42:49.637364: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# ...

# %%
# !python /content/yolov5/detect.py --source /content/paragliderTest.jpg
# Out:
# detect: weights=yolov5/yolov5s.pt, source=/content/paragliderTest.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-383-g1435a8ee Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/paragliderTest.jpg: 640x480 2 persons, 1 kite, 44.5ms
# Speed: 0.6ms pre-process, 44.5ms inference, 825.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp6

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp6/weights/best.pt --img 640 --conf 0.25 --source /content/paragliderTest.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp6/weights/best.pt'], source=/content/paragliderTest.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-383-g1435a8ee Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/paragliderTest.jpg: 640x480 2 paragliders, 27.1ms
# Speed: 0.5ms pre-process, 27.1ms inference, 574.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp7

# %%
# !ls -l /content/yolov5/dataset/roboflowParagliderDataset/valid/images
# Out:
# ls: cannot access '/content/yolov5/dataset/roboflowParagliderDataset/valid/images': No such file or directory
